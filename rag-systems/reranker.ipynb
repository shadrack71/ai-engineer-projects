# %%
# %pip install langchain_cohere
# Out:
# Collecting langchain_cohere
#   Downloading langchain_cohere-0.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting cohere<6.0,>=5.18.0 (from langchain_cohere)
#   Downloading cohere-5.21.1-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: langchain-community<0.5.0,>=0.4.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from langchain_cohere) (0.4.1)
# Requirement already satisfied: langchain-core<2.0,>=1.0.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from langchain_cohere) (1.2.22)
# Requirement already satisfied: pydantic<3,>=2 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from langchain_cohere) (2.12.4)
# Collecting types-pyyaml<7.0.0.0,>=6.0.12.20240917 (from langchain_cohere)
#   Downloading types_pyyaml-6.0.12.20250915-py3-none-any.whl.metadata (1.7 kB)
# Collecting fastavro<2.0.0,>=1.9.4 (from cohere<6.0,>=5.18.0->langchain_cohere)
#   Downloading fastavro-1.12.1-cp312-cp312-win_amd64.whl.metadata (5.9 kB)
# Requirement already satisfied: httpx>=0.21.2 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from cohere<6.0,>=5.18.0->langchain_cohere) (0.28.1)
# Requirement already satisfied: pydantic-core>=2.18.2 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from cohere<6.0,>=5.18.0->langchain_cohere) (2.41.5)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from cohere<6.0,>=5.18.0->langchain_cohere) (2.32.5)
# Requirement already satisfied: tokenizers<1,>=0.15 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from cohere<6.0,>=5.18.0->langchain_cohere) (0.22.1)
# Collecting types-requests<3.0.0,>=2.0.0 (from cohere<6.0,>=5.18.0->langchain_cohere)
#   Downloading types_requests-2.32.4.20260324-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing_extensions>=4.0.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from cohere<6.0,>=5.18.0->langchain_cohere) (4.15.0)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain_cohere) (1.0.3)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain_cohere) (2.0.44)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain_cohere) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain_cohere) (3.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain_cohere) (8.5.0)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain_cohere) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain_cohere) (2.11.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain_cohere) (0.7.20)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain_cohere) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from langchain-community<0.5.0,>=0.4.0->langchain_cohere) (2.4.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain_cohere) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain_cohere) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain_cohere) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain_cohere) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain_cohere) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain_cohere) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.5.0,>=0.4.0->langchain_cohere) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community<0.5.0,>=0.4.0->langchain_cohere) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community<0.5.0,>=0.4.0->langchain_cohere) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.1 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community<0.5.0,>=0.4.0->langchain_cohere) (1.1.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from langchain-core<2.0,>=1.0.0->langchain_cohere) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from langchain-core<2.0,>=1.0.0->langchain_cohere) (24.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from langchain-core<2.0,>=1.0.0->langchain_cohere) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0,>=1.0.0->langchain_cohere) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<0.5.0,>=0.4.0->langchain_cohere) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<0.5.0,>=0.4.0->langchain_cohere) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<0.5.0,>=0.4.0->langchain_cohere) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<0.5.0,>=0.4.0->langchain_cohere) (0.25.0)
# Requirement already satisfied: anyio in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain_cohere) (4.11.0)
# Requirement already satisfied: certifi in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain_cohere) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain_cohere) (1.0.9)
# Requirement already satisfied: idna in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain_cohere) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from httpcore==1.*->httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain_cohere) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from pydantic<3,>=2->langchain_cohere) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from pydantic<3,>=2->langchain_cohere) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community<0.5.0,>=0.4.0->langchain_cohere) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from requests<3.0.0,>=2.0.0->cohere<6.0,>=5.18.0->langchain_cohere) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from requests<3.0.0,>=2.0.0->cohere<6.0,>=5.18.0->langchain_cohere) (2.3.0)
# Requirement already satisfied: greenlet>=1 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community<0.5.0,>=0.4.0->langchain_cohere) (3.2.4)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain_cohere) (1.8.0)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain_cohere) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain_cohere) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain_cohere) (1.4.2)
# Requirement already satisfied: tqdm>=4.42.1 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain_cohere) (4.67.3)
# Requirement already satisfied: typer in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain_cohere) (0.20.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community<0.5.0,>=0.4.0->langchain_cohere) (1.1.0)
# Requirement already satisfied: colorama in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from tqdm>=4.42.1->huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain_cohere) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from anyio->httpx>=0.21.2->cohere<6.0,>=5.18.0->langchain_cohere) (1.3.1)
# Requirement already satisfied: click>=8.0.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain_cohere) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain_cohere) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain_cohere) (14.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from rich>=10.11.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain_cohere) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from rich>=10.11.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain_cohere) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\User\anaconda3\envs\py312\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer->huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.15->cohere<6.0,>=5.18.0->langchain_cohere) (0.1.2)
# Downloading langchain_cohere-0.5.0-py3-none-any.whl (42 kB)
# Downloading cohere-5.21.1-py3-none-any.whl (334 kB)
# Downloading fastavro-1.12.1-cp312-cp312-win_amd64.whl (444 kB)
# Downloading types_pyyaml-6.0.12.20250915-py3-none-any.whl (20 kB)
# Downloading types_requests-2.32.4.20260324-py3-none-any.whl (20 kB)
# Installing collected packages: types-requests, types-pyyaml, fastavro, cohere, langchain_cohere
#
#    -------- ------------------------------- 1/5 [types-pyyaml]
#    ---------------- ----------------------- 2/5 [fastavro]
#    ---------------- ----------------------- 2/5 [fastavro]
#    ---------------- ----------------------- 2/5 [fastavro]
#    ------------------------ --------------- 3/5 [cohere]
#    ------------------------ --------------- 3/5 [cohere]
#    ------------------------ --------------- 3/5 [cohere]
#    ------------------------ --------------- 3/5 [cohere]
#    ------------------------ --------------- 3/5 [cohere]
#    ------------------------ --------------- 3/5 [cohere]
#    ------------------------ --------------- 3/5 [cohere]
#    ------------------------ --------------- 3/5 [cohere]
#    ------------------------ --------------- 3/5 [cohere]
#    ------------------------ --------------- 3/5 [cohere]
#    ------------------------ --------------- 3/5 [cohere]
#    ------------------------ --------------- 3/5 [cohere]
#    ------------------------ --------------- 3/5 [cohere]
#    ------------------------ --------------- 3/5 [cohere]
#    ------------------------ --------------- 3/5 [cohere]
#    ------------------------ --------------- 3/5 [cohere]
#    ------------------------ --------------- 3/5 [cohere]
#    ------------------------ --------------- 3/5 [cohere]
#    ------------------------ --------------- 3/5 [cohere]
#    ------------------------ --------------- 3/5 [cohere]
#    ------------------------ --------------- 3/5 [cohere]
#    ------------------------ --------------- 3/5 [cohere]
#    ------------------------ --------------- 3/5 [cohere]
#    ------------------------ --------------- 3/5 [cohere]
#    ------------------------ --------------- 3/5 [cohere]
#    -------------------------------- ------- 4/5 [langchain_cohere]
#    -------------------------------- ------- 4/5 [langchain_cohere]
#    ---------------------------------------- 5/5 [langchain_cohere]
#
# Successfully installed cohere-5.21.1 fastavro-1.12.1 langchain_cohere-0.5.0 types-pyyaml-6.0.12.20250915 types-requests-2.32.4.20260324
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\User\anaconda3\envs\py312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\User\anaconda3\envs\py312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\User\anaconda3\envs\py312\Lib\site-packages)

# %%
from langchain_community.retrievers import BM25Retriever
from langchain_classic.retrievers import EnsembleRetriever
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma
from langchain_core.documents import Document
from langchain_cohere import CohereRerank
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
chunks = [
    # Tesla - Financial & Production
    "Tesla reported record quarterly revenue of $25.2 billion in Q3 2024.",
    "Tesla's automotive gross margin improved to 19.3% this quarter.",
    "Tesla Cybertruck production ramp begins in 2024 with initial deliveries.",
    "Tesla announced plans to expand Gigafactory production capacity.",
    "Tesla stock price reached new highs following earnings announcement.",
    "Tesla's energy storage business grew 40% year-over-year.",
    "Tesla continues to lead in electric vehicle market share globally.",
    "Tesla Model Y became the best-selling vehicle worldwide.",
    "Tesla reported strong free cash flow generation of $7.5 billion.",
    "Tesla's Full Self-Driving revenue increased significantly.",

    # Microsoft - Development & Acquisitions
    "Microsoft acquired GitHub for $7.5 billion in 2018.",
    "Microsoft's cloud revenue Azure grew 29% year-over-year.",
    "Microsoft announced new AI features for Visual Studio Code.",
    "Microsoft Teams integration with GitHub enhances developer workflow.",
    "Microsoft's developer tools division sees strong adoption.",
    "Microsoft acquired Activision Blizzard for $68.7 billion.",
    "Microsoft's productivity suite gained 50 million new users.",
    "Microsoft announced new Surface devices for developers.",
    "Microsoft's AI Copilot features expand to more development tools.",
    "Microsoft's enterprise solutions drive revenue growth.",

    # NVIDIA - AI & Hardware
    "NVIDIA's data center revenue reached $47.5 billion annually.",
    "NVIDIA's H100 GPUs see unprecedented demand for AI training.",
    "NVIDIA announced next-generation Blackwell architecture.",
    "NVIDIA's gaming revenue declined due to crypto market changes.",
    "NVIDIA's automotive AI platform partnerships expanded.",
    "NVIDIA's AI chip shortage affects cloud providers.",
    "NVIDIA stock valuation exceeds $2 trillion market cap.",
    "NVIDIA's CUDA platform dominates AI development.",
    "NVIDIA announced new AI inference chips for edge computing.",
    "NVIDIA's partnership with major cloud providers strengthens.",

    # Google/Alphabet - AI & Cloud
    "Google's AI investments total over $100 billion in recent years.",
    "Google Cloud revenue grew 35% reaching $8.4 billion quarterly.",
    "Google announced Gemini AI model competing with GPT-4.",
    "Google's search advertising revenue remains strong at $59 billion.",
    "Google's Workspace products integrate advanced AI features.",
    "Google announced quantum computing breakthroughs.",
    "Google's autonomous vehicle division Waymo expands operations.",
    "Google's AI research published breakthrough papers.",
    "Google's cloud AI services see enterprise adoption.",
    "Google faces regulatory scrutiny over AI dominance.",

    # Noisy/Less Relevant Chunks
    "The Tesla coil was invented by Nikola Tesla in 1891.",
    "Microsoft Excel spreadsheet formulas can be complex for beginners.",
    "NVIDIA Shield TV streaming device gets software update.",
    "Google Maps navigation improved with real-time traffic data.",
    "Production delays affected multiple manufacturing sectors.",
    "Financial markets showed volatility during earnings season.",
    "Revenue recognition standards changed for software companies.",
    "Hardware components face supply chain constraints globally.",
    "Development tools market grows with remote work trends.",
    "AI research requires significant computational resources.",
    "Quarterly reports show mixed results across tech sector.",
    "Stock market analysts upgrade technology sector ratings.",
    "Cloud computing adoption accelerates in enterprise market.",
    "Data center construction increases globally.",
    "Semiconductor shortage impacts various industries.",
    "Electric vehicle charging infrastructure expands rapidly.",
    "Software development productivity tools gain popularity.",
    "Machine learning frameworks become more accessible.",
    "Enterprise software licensing models evolve.",
    "Technology conferences showcase latest innovations."
]

print(f"Created {len(chunks)} sample chunks for demonstration")
# Out:
# Created 60 sample chunks for demonstration

# %%
# Convert to Document objects
documents = [Document(page_content=chunk, metadata={"source": f"chunk_{i}"}) for i, chunk in enumerate(chunks)]

# %%
embedding_model = OpenAIEmbeddings(model="text-embedding-3-small")
vectorstore = Chroma.from_documents(
    documents=documents,
    embedding=embedding_model,
    collection_metadata={"hnsw:space": "cosine"}
)
vector_retriever = vectorstore.as_retriever(search_kwargs={"k": 15})

# %%
# 2. BM25 Retriever
bm25_retriever = BM25Retriever.from_documents(documents)
bm25_retriever.k = 15

# %%
hybrid_retriever = EnsembleRetriever(
    retrievers=[vector_retriever, bm25_retriever],
    weights=[0.7, 0.3]
)

print("Setup complete!\n")
# Out:
# Setup complete!

# %%
query = "Tesla financial performance and production updates"

print("STEP 1: Hybrid Search Results")
print("-"*50)

retrieved_docs = hybrid_retriever.invoke(query)  # Get top 25 for reranking

# Show top 10 from hybrid search
for i, doc in enumerate(retrieved_docs, 1):
    print(f"{i:2d}. {doc.page_content}")

print(f"\n(Retrieved {len(retrieved_docs)} total chunks for reranking)\n")
# Out:
# STEP 1: Hybrid Search Results
# --------------------------------------------------
#  1. Tesla announced plans to expand Gigafactory production capacity.
#  2. Tesla reported strong free cash flow generation of $7.5 billion.
#  3. Tesla stock price reached new highs following earnings announcement.
#  4. Tesla reported record quarterly revenue of $25.2 billion in Q3 2024.
#  5. Tesla Cybertruck production ramp begins in 2024 with initial deliveries.
#  6. Tesla continues to lead in electric vehicle market share globally.
#  7. Tesla Model Y became the best-selling vehicle worldwide.
#  8. Financial markets showed volatility during earnings season.
#  9. Tesla's automotive gross margin improved to 19.3% this quarter.
# 10. Tesla's Full Self-Driving revenue increased significantly.
# 11. Tesla's energy storage business grew 40% year-over-year.
# 12. Quarterly reports show mixed results across tech sector.
# 13. NVIDIA's automotive AI platform partnerships expanded.
# 14. Stock market analysts upgrade technology sector ratings.
# 15. NVIDIA stock valuation exceeds $2 trillion market cap.
# 16. The Tesla coil was invented by Nikola Tesla in 1891.
# 17. Electric vehicle charging infrastructure expands rapidly.
# 18. Technology conferences showcase latest innovations.
# 19. Machine learning frameworks become more accessible.
# 20. Enterprise software licensing models evolve.
# 21. Development tools market grows with remote work trends.
# 22. Hardware components face supply chain constraints globally.
#
# (Retrieved 22 total chunks for reranking)

# %%
print("STEP 2: After Cohere Reranking (Top 10)")
print("-"*50)

# Initialize Cohere reranker
reranker = CohereRerank(model="rerank-english-v3.0", top_n=10)

# Rerank the retrieved documents
reranked_docs = reranker.compress_documents(retrieved_docs, query)

# Show reranked results
for i, doc in enumerate(reranked_docs, 1):
    print(f"{i:2d}. {doc.page_content}")

print("\n" + "="*80)
print("ANALYSIS:")
print("Hybrid Search: Mixed relevant and irrelevant results")
print("Reranking: Most relevant Tesla financial/production info at top")
print("Notice how reranking moved the most contextually relevant chunks higher")

# Optional: Show the difference more clearly
print("\n" + "="*80)
print("KEY IMPROVEMENTS AFTER RERANKING:")
print("-"*40)


hybrid_top_5 = [doc.page_content for doc in retrieved_docs[:5]]
reranked_top_5= [doc.page_content for doc in reranked_docs[:5]]

print("BEFORE (Hybrid Top 3):")
for i, content in enumerate(hybrid_top_5, 1):
    print(f"  {i}. {content}")

print("\nAFTER (Reranked Top 3):")
for i, content in enumerate(reranked_top_5, 1):
    print(f"  {i}. {content}")
# Out:
# STEP 2: After Cohere Reranking (Top 10)
# --------------------------------------------------
#  1. Tesla reported strong free cash flow generation of $7.5 billion.
#  2. Tesla reported record quarterly revenue of $25.2 billion in Q3 2024.
#  3. Tesla's automotive gross margin improved to 19.3% this quarter.
#  4. Tesla announced plans to expand Gigafactory production capacity.
#  5. Tesla's energy storage business grew 40% year-over-year.
#  6. Tesla continues to lead in electric vehicle market share globally.
#  7. Tesla's Full Self-Driving revenue increased significantly.
#  8. Tesla Cybertruck production ramp begins in 2024 with initial deliveries.
#  9. Tesla stock price reached new highs following earnings announcement.
# 10. Financial markets showed volatility during earnings season.
#
# ================================================================================
# ANALYSIS:
# ✅ Hybrid Search: Mixed relevant and irrelevant results
# ✅ Reranking: Most relevant Tesla financial/production info at top
# ✅ Notice how reranking moved the most contextually relevant chunks higher
#
# ================================================================================
# KEY IMPROVEMENTS AFTER RERANKING:
# ----------------------------------------
# BEFORE (Hybrid Top 3):
#   1. Tesla announced plans to expand Gigafactory production capacity.
#   2. Tesla reported strong free cash flow generation of $7.5 billion.
#   3. Tesla stock price reached new highs following earnings announcement.
#   4. Tesla reported record quarterly revenue of $25.2 billion in Q3 2024.
#   5. Tesla Cybertruck production ramp begins in 2024 with initial deliveries.
#
# AFTER (Reranked Top 3):
#   1. Tesla reported strong free cash flow generation of $7.5 billion.
#   2. Tesla reported record quarterly revenue of $25.2 billion in Q3 2024.
#   3. Tesla's automotive gross margin improved to 19.3% this quarter.
#   4. Tesla announced plans to expand Gigafactory production capacity.
#   5. Tesla's energy storage business grew 40% year-over-year.

# %%
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_openai import ChatOpenAI

print("\n" + "="*80)
print("FINAL: RAG with Reranked Context")
print("-"*40)

# Use top 5 reranked documents for final answer
top_reranked = reranked_docs[:5]

combined_input = f"""Based on the following documents, please answer this question: {query}

Documents:
{chr(10).join([f"- {doc.page_content}" for doc in top_reranked])}

Please provide a clear, helpful answer using only the information from these documents."""

model = ChatOpenAI(model="gpt-4o")
messages = [
    SystemMessage(content="You are a helpful assistant."),
    HumanMessage(content=combined_input),
]

result = model.invoke(messages)
print("Generated Response:")
print(result.content)
# Out:
# ================================================================================
# FINAL: RAG with Reranked Context
# ----------------------------------------
# Generated Response:
# Tesla's financial performance has been strong, with the company generating $7.5 billion in free cash flow and achieving a record quarterly revenue of $25.2 billion in Q3 2024. The company's automotive gross margin improved to 19.3% this quarter. In terms of production updates, Tesla announced plans to expand its Gigafactory production capacity. Additionally, Tesla's energy storage business experienced significant growth, increasing by 40% year-over-year.
